# %% [markdown]
# Ask the user for various words (nouns, adjectives, verbs) using input(), store them in variables, and then inject them into a funny pre-written story using f-strings and print().

# %%
adjective = input ("Enter a adjective")
noun = input ("Enter a noun")
verb = input ("Enter a verb")
print (f"I was {adjective} while working on my assignment, becuase my {noun} asked me to make other people {verb} ")
# Out:
# Enter a adjective stuck
# Enter a noun teacher
# Enter a verb luagh
# I was stuck while working on my assignment, becuase my teacher asked me to make other people luagh
